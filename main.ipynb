# %% [markdown]
# Dependencies

# %%
import gymnasium as gym
import gym_anytrading
import pandas as pd
import numpy as np
import os

from stable_baselines3 import PPO
from matplotlib import pyplot as plt
from gym_anytrading.envs import StocksEnv
from stable_baselines3.common.vec_env import DummyVecEnv
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# Data Preparation

# %%
header_names = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']
df = pd.read_csv('eth_usdt_5m.csv', header=None, names=header_names)

df['Date'] = pd.to_datetime(df['Date'], unit='ms')
df.set_index('Date', inplace=True)
df = df.sort_index(ascending=True)

df['Day_Of_Week'] = df.index.day_of_week
df['Time_of_Day'] = df.index.astype('int64') // 10**9

df['Close_pct_change'] = df['Close'].pct_change() * 100

df['Typical_Price'] = (df['High'] + df['Low'] + df['Close']) / 3
df['Volume_Weighted_Price'] = df['Typical_Price'] * df['Volume']
df['Cumulative_Volume_Weighted_Price'] = df['Volume_Weighted_Price'].cumsum()
df['Cumulative_Volume'] = df['Volume'].cumsum()
df['VWAP'] = df['Cumulative_Volume_Weighted_Price'] / df['Cumulative_Volume']

df = df[['Day_Of_Week','Time_of_Day', 'Close', 'Volume', 'Close_pct_change', 'VWAP']]

df.head(10)
# Out:
#                      Day_Of_Week  Time_of_Day    Close   Volume
# Date
# 2021-03-15 00:00:00            0   1615766400  1858.45  1822.14  \
# 2021-03-15 00:05:00            0   1615766700  1863.00   779.20
# 2021-03-15 00:10:00            0   1615767000  1863.90   199.95
# 2021-03-15 00:15:00            0   1615767300  1872.05   214.51
# 2021-03-15 00:20:00            0   1615767600  1878.30   264.05
# 2021-03-15 00:25:00            0   1615767900  1878.45   188.07
# 2021-03-15 00:30:00            0   1615768200  1876.90   183.79
# 2021-03-15 00:35:00            0   1615768500  1878.85    81.60
# 2021-03-15 00:40:00            0   1615768800  1880.15   175.66
# 2021-03-15 00:45:00            0   1615769100  1879.40    95.80
#
#                      Close_pct_change         VWAP
# Date
# 2021-03-15 00:00:00               NaN  1853.750000
# 2021-03-15 00:05:00          0.244828  1856.101373
# 2021-03-15 00:10:00          0.048309  1856.660401
# 2021-03-15 00:15:00          0.437255  1857.540472
# 2021-03-15 00:20:00          0.333859  1859.023905
# 2021-03-15 00:25:00          0.007986  1860.106332
# 2021-03-15 00:30:00         -0.082515  1860.942327
# 2021-03-15 00:35:00          0.103895  1861.324997
# 2021-03-15 00:40:00          0.069191  1862.133501
# 2021-03-15 00:45:00         -0.039890  1862.591194

# %%
header_names = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']
btc_df = pd.read_csv('btc_usdt_5m.csv', header=None, names=header_names)
btc_df = btc_df[['Date', 'Close']]
btc_df['Date'] = pd.to_datetime(btc_df['Date'], unit='ms')
btc_df.set_index('Date', inplace=True)
btc_df = btc_df.sort_index(ascending=True)
btc_df['btc_close_pct_change'] = btc_df['Close'].pct_change() * 100
btc_df.head(5)
# Out:
#                        Close  btc_close_pct_change
# Date
# 2021-03-14 00:45:00  61360.0                   NaN
# 2021-03-14 00:50:00  61434.5              0.121415
# 2021-03-14 00:55:00  61386.5             -0.078132
# 2021-03-14 01:00:00  61119.0             -0.435764
# 2021-03-14 01:05:00  60958.0             -0.263421

# %%
df['btc_close_pct_change'] = btc_df['btc_close_pct_change']
df['btc_close_pct_change'] = df['btc_close_pct_change'].fillna(method='ffill')
df=df.dropna()
df.head(5)
# Out:
#                      Day_Of_Week  Time_of_Day    Close  Volume
# Date
# 2021-03-15 00:05:00            0   1615766700  1863.00  779.20  \
# 2021-03-15 00:10:00            0   1615767000  1863.90  199.95
# 2021-03-15 00:15:00            0   1615767300  1872.05  214.51
# 2021-03-15 00:20:00            0   1615767600  1878.30  264.05
# 2021-03-15 00:25:00            0   1615767900  1878.45  188.07
#
#                      Close_pct_change         VWAP  btc_close_pct_change
# Date
# 2021-03-15 00:05:00          0.244828  1856.101373              0.187133
# 2021-03-15 00:10:00          0.048309  1856.660401              0.133778
# 2021-03-15 00:15:00          0.437255  1857.540472              0.452051
# 2021-03-15 00:20:00          0.333859  1859.023905              0.185695
# 2021-03-15 00:25:00          0.007986  1860.106332              0.134421

# %%
hourly_df = df.resample('1h').agg({'Close': 'last'})
hourly_df.head(5)
# Out:
#                        Close
# Date
# 2021-03-15 00:00:00  1874.65
# 2021-03-15 01:00:00  1887.30
# 2021-03-15 02:00:00  1885.20
# 2021-03-15 03:00:00  1886.50
# 2021-03-15 04:00:00  1864.05

# %%
hourly_df['hourly_close_pct_change'] = hourly_df['Close'].pct_change() * 100
hourly_df.head(5)
# Out:
#                        Close  hourly_close_pct_change
# Date
# 2021-03-15 00:00:00  1874.65                      NaN
# 2021-03-15 01:00:00  1887.30                 0.674793
# 2021-03-15 02:00:00  1885.20                -0.111270
# 2021-03-15 03:00:00  1886.50                 0.068958
# 2021-03-15 04:00:00  1864.05                -1.190034

# %%
df['hourly_close_pct_change'] = hourly_df['hourly_close_pct_change']
df['hourly_close_pct_change'] = df['hourly_close_pct_change'].fillna(method='ffill')
df=df.dropna()
df.head(5)
# Out:
#                      Day_Of_Week  Time_of_Day    Close  Volume
# Date
# 2021-03-15 01:00:00            0   1615770000  1880.00  314.39  \
# 2021-03-15 01:05:00            0   1615770300  1873.50  261.52
# 2021-03-15 01:10:00            0   1615770600  1877.75  347.76
# 2021-03-15 01:15:00            0   1615770900  1880.80  148.73
# 2021-03-15 01:20:00            0   1615771200  1887.20  198.39
#
#                      Close_pct_change         VWAP  btc_close_pct_change
# Date
# 2021-03-15 01:00:00          0.285387  1864.964786              0.125822  \
# 2021-03-15 01:05:00         -0.345745  1865.492750             -0.214466
# 2021-03-15 01:10:00          0.226848  1866.160428              0.391235
# 2021-03-15 01:15:00          0.162428  1866.497642              0.064394
# 2021-03-15 01:20:00          0.340281  1867.123454              0.407846
#
#                      hourly_close_pct_change
# Date
# 2021-03-15 01:00:00                 0.674793
# 2021-03-15 01:05:00                 0.674793
# 2021-03-15 01:10:00                 0.674793
# 2021-03-15 01:15:00                 0.674793
# 2021-03-15 01:20:00                 0.674793

# %%
scaled_columns = ['Day_Of_Week',
                'Time_of_Day',
                'Close', 
                'Volume',
                'Close_pct_change',
                'VWAP',
                'btc_close_pct_change',
                'hourly_close_pct_change']
scaler = MinMaxScaler()
df[scaled_columns] = scaler.fit_transform(df[scaled_columns])

# %%
df.dtypes
# Out:
# Day_Of_Week                float64
# Time_of_Day                float64
# Close                      float64
# Volume                     float64
# Close_pct_change           float64
# VWAP                       float64
# btc_close_pct_change       float64
# hourly_close_pct_change    float64
# dtype: object

# %%
def add_signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Close'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['Day_Of_Week',
                                    'Time_of_Day',
                                    'Close', 
                                    'Volume',
                                    'Close_pct_change',
                                    'VWAP',
                                    'btc_close_pct_change',
                                    'hourly_close_pct_change']].to_numpy()[start:end]
    return prices, signal_features

# %% [markdown]
# Custom Environment

# %%
class MyCustomEnv(StocksEnv):
    _process_data = add_signals

env2 = MyCustomEnv(df=df, window_size = 24, frame_bound=(24,258300))

# %%
env_maker = lambda: env2
env = DummyVecEnv([env_maker])

# %% [markdown]
# Tensorboard Log

# %%
log_path = os.path.join('model', 'Log')

# %% [markdown]
# Model Training

# %%
model = PPO('MlpPolicy',
        env,
        learning_rate=5e-5,
        gamma=0.95,
        ent_coef=0.03,
        target_kl=0.01,
        verbose=1,
        tensorboard_log=log_path) 
model.learn(total_timesteps=100000000)
# Out:
# Using cpu device
# Logging to model\Log\PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 691  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 473           |
# |    iterations           | 2             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00090570224 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.0889       |
# |    learning_rate        | 5e-05         |
# |    loss                 | -0.0225       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000268     |
# |    value_loss           | 0.00053       |
# -------------------------------------------
# Early stopping at step 7 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013032228 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | -0.263      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.00504    |
# |    n_updates            | 18          |
# |    policy_gradient_loss | -0.00371    |
# |    value_loss           | 0.000364    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 4            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0050432375 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.675       |
# |    explained_variance   | -0.367       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0175      |
# |    n_updates            | 28           |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 0.000182     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 401          |
# |    iterations           | 5            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0071926983 |
# |    clip_fraction        | 0.00659      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.676       |
# |    explained_variance   | -0.762       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0239      |
# |    n_updates            | 38           |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 0.000122     |
# ------------------------------------------
# Early stopping at step 7 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 6           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014587485 |
# |    clip_fraction        | 0.009       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.692      |
# |    explained_variance   | -1.68       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0359     |
# |    n_updates            | 46          |
# |    policy_gradient_loss | -0.00336    |
# |    value_loss           | 0.000189    |
# -----------------------------------------
# Early stopping at step 7 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 7           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013549373 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | -3.97       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0303     |
# |    n_updates            | 54          |
# |    policy_gradient_loss | -0.00395    |
# |    value_loss           | 0.000194    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 8            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0068333494 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.676       |
# |    explained_variance   | -3.96        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0257      |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.000902    |
# |    value_loss           | 8.97e-05     |
# ------------------------------------------
# Early stopping at step 9 due to reaching max kl: 0.02
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 467       |
# |    iterations           | 9         |
# |    time_elapsed         | 39        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0145927 |
# |    clip_fraction        | 0.00107   |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.691    |
# |    explained_variance   | -1.19     |
# |    learning_rate        | 5e-05     |
# |    loss                 | -0.025    |
# |    n_updates            | 74        |
# |    policy_gradient_loss | -0.00282  |
# |    value_loss           | 0.000117  |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 475          |
# |    iterations           | 10           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0004019323 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | -2.51        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.024       |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.000283    |
# |    value_loss           | 0.000204     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 11          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010331035 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | -3.38       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0335     |
# |    n_updates            | 94          |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 0.000444    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 485         |
# |    iterations           | 12          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010178669 |
# |    clip_fraction        | 0.00835     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | -0.919      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0132     |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 0.000136    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 13          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007995645 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.683      |
# |    explained_variance   | -1.45       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0273     |
# |    n_updates            | 114         |
# |    policy_gradient_loss | -0.00149    |
# |    value_loss           | 4.95e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 491          |
# |    iterations           | 14           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0016278224 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.667       |
# |    explained_variance   | -2.53        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0162      |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.00039     |
# |    value_loss           | 5.65e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 492           |
# |    iterations           | 15            |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00023953771 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.656        |
# |    explained_variance   | -2.68         |
# |    learning_rate        | 5e-05         |
# |    loss                 | -0.0166       |
# |    n_updates            | 134           |
# |    policy_gradient_loss | -5.18e-05     |
# |    value_loss           | 4.72e-05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 489          |
# |    iterations           | 16           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0017457493 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.645       |
# |    explained_variance   | -2.75        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0262      |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.000382    |
# |    value_loss           | 6.89e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 483         |
# |    iterations           | 17          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.001073976 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.641      |
# |    explained_variance   | -2.21       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0261     |
# |    n_updates            | 154         |
# |    policy_gradient_loss | 0.000101    |
# |    value_loss           | 3.66e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 18          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009112997 |
# |    clip_fraction        | 0.0149      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | -1.91       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0379     |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.00154    |
# |    value_loss           | 2.8e-05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 19          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.013031361 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.69       |
# |    explained_variance   | -3.91       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0202     |
# |    n_updates            | 174         |
# |    policy_gradient_loss | -0.00413    |
# |    value_loss           | 2.91e-05    |
# -----------------------------------------
# Early stopping at step 6 due to reaching max kl: 0.02
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 461          |
# |    iterations           | 20           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0140790865 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | -3.18        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0189       |
# |    n_updates            | 181          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 4.1e-05      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 457           |
# |    iterations           | 21            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00033964182 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.674        |
# |    explained_variance   | -4.02         |
# |    learning_rate        | 5e-05         |
# |    loss                 | -0.0172       |
# |    n_updates            | 191           |
# |    policy_gradient_loss | -0.00028      |
# |    value_loss           | 2.87e-05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 452          |
# |    iterations           | 22           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0005082011 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.673       |
# |    explained_variance   | -2.45        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0164      |
# |    n_updates            | 201          |
# |    policy_gradient_loss | 6.24e-05     |
# |    value_loss           | 3.39e-05     |
# ------------------------------------------
# Early stopping at step 9 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 23          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012739498 |
# |    clip_fraction        | 0.00113     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | -1.98       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.000381   |
# |    n_updates            | 211         |
# |    policy_gradient_loss | -0.00266    |
# |    value_loss           | 2.39e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 24          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008859638 |
# |    clip_fraction        | 0.0213      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.656      |
# |    explained_variance   | -2.44       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0321     |
# |    n_updates            | 221         |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 1.78e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 430          |
# |    iterations           | 25           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0055850344 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.655       |
# |    explained_variance   | -2.01        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0124      |
# |    n_updates            | 231          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 1.81e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 26          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005683991 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.654      |
# |    explained_variance   | -1.96       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0135     |
# |    n_updates            | 241         |
# |    policy_gradient_loss | -2.39e-06   |
# |    value_loss           | 3.38e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 27          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.000986391 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | -0.701      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0254     |
# |    n_updates            | 251         |
# |    policy_gradient_loss | 9.96e-05    |
# |    value_loss           | 3.55e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 424         |
# |    iterations           | 28          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.001549731 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.683      |
# |    explained_variance   | -0.853      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0263     |
# |    n_updates            | 261         |
# |    policy_gradient_loss | 0.000102    |
# |    value_loss           | 2.9e-05     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 29           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0018983034 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.682       |
# |    explained_variance   | -0.806       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0231      |
# |    n_updates            | 271          |
# |    policy_gradient_loss | -0.000673    |
# |    value_loss           | 2.82e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 30          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.005327225 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | -1.11       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0337     |
# |    n_updates            | 281         |
# |    policy_gradient_loss | -0.000155   |
# |    value_loss           | 1.75e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 31          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008140918 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | -0.841      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.00651    |
# |    n_updates            | 291         |
# |    policy_gradient_loss | -0.000992   |
# |    value_loss           | 1.85e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 32          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004699343 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -0.702      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0167     |
# |    n_updates            | 301         |
# |    policy_gradient_loss | -0.000623   |
# |    value_loss           | 1.71e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 33          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011887481 |
# |    clip_fraction        | 0.0254      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.688      |
# |    explained_variance   | -0.33       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0203     |
# |    n_updates            | 311         |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 2.14e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 430          |
# |    iterations           | 34           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0012419489 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | -0.244       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0263      |
# |    n_updates            | 321          |
# |    policy_gradient_loss | -0.000323    |
# |    value_loss           | 1.97e-05     |
# ------------------------------------------
# Early stopping at step 6 due to reaching max kl: 0.02
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 434        |
# |    iterations           | 35         |
# |    time_elapsed         | 164        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.01345496 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.681     |
# |    explained_variance   | -0.29      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.00261   |
# |    n_updates            | 328        |
# |    policy_gradient_loss | -0.0033    |
# |    value_loss           | 1.74e-05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 36          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010892479 |
# |    clip_fraction        | 0.0215      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.679      |
# |    explained_variance   | -0.101      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.00793    |
# |    n_updates            | 338         |
# |    policy_gradient_loss | -0.0013     |
# |    value_loss           | 3.4e-05     |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 438           |
# |    iterations           | 37            |
# |    time_elapsed         | 172           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00012809853 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.686        |
# |    explained_variance   | 0.00908       |
# |    learning_rate        | 5e-05         |
# |    loss                 | -0.0209       |
# |    n_updates            | 348           |
# |    policy_gradient_loss | 7.56e-05      |
# |    value_loss           | 2.84e-05      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 38          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.010661791 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.674      |
# |    explained_variance   | 0.0747      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.034      |
# |    n_updates            | 358         |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 2.82e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 442         |
# |    iterations           | 39          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011025367 |
# |    clip_fraction        | 0.0453      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.0321      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.017      |
# |    n_updates            | 368         |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 5.06e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 40          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007477888 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 0.0446      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0218     |
# |    n_updates            | 378         |
# |    policy_gradient_loss | -0.00105    |
# |    value_loss           | 2.44e-05    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 445           |
# |    iterations           | 41            |
# |    time_elapsed         | 188           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00059568393 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | -0.295        |
# |    learning_rate        | 5e-05         |
# |    loss                 | -0.027        |
# |    n_updates            | 388           |
# |    policy_gradient_loss | -0.000131     |
# |    value_loss           | 1.76e-05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 447           |
# |    iterations           | 42            |
# |    time_elapsed         | 192           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00017227128 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | -0.461        |
# |    learning_rate        | 5e-05         |
# |    loss                 | -0.0236       |
# |    n_updates            | 398           |
# |    policy_gradient_loss | 2.2e-05       |
# |    value_loss           | 1.04e-05      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 449         |
# |    iterations           | 43          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.002007519 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | -0.0686     |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0167     |
# |    n_updates            | 408         |
# |    policy_gradient_loss | -0.000268   |
# |    value_loss           | 1.43e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 450          |
# |    iterations           | 44           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0029207417 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.692       |
# |    explained_variance   | -0.189       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0195      |
# |    n_updates            | 418          |
# |    policy_gradient_loss | -0.000643    |
# |    value_loss           | 2.17e-05     |
# ------------------------------------------
# Early stopping at step 7 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 45          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.014561784 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.689      |
# |    explained_variance   | -0.161      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0158     |
# |    n_updates            | 426         |
# |    policy_gradient_loss | -0.00228    |
# |    value_loss           | 1.05e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 454          |
# |    iterations           | 46           |
# |    time_elapsed         | 207          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0011696863 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.684       |
# |    explained_variance   | -0.352       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0201      |
# |    n_updates            | 436          |
# |    policy_gradient_loss | 7.85e-05     |
# |    value_loss           | 3.84e-05     |
# ------------------------------------------
# Early stopping at step 4 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 47          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.014318078 |
# |    clip_fraction        | 0.00104     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.692      |
# |    explained_variance   | -0.484      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.037      |
# |    n_updates            | 441         |
# |    policy_gradient_loss | -0.00411    |
# |    value_loss           | 1.46e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 48          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010242787 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | -0.00592    |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0114      |
# |    n_updates            | 451         |
# |    policy_gradient_loss | -0.00157    |
# |    value_loss           | 1.4e-05     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 49           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0026803548 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.675       |
# |    explained_variance   | -0.0389      |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.024       |
# |    n_updates            | 461          |
# |    policy_gradient_loss | -0.000728    |
# |    value_loss           | 1.18e-05     |
# ------------------------------------------
# Early stopping at step 5 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 50          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.014231691 |
# |    clip_fraction        | 0.0127      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.689      |
# |    explained_variance   | -0.113      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0136     |
# |    n_updates            | 467         |
# |    policy_gradient_loss | -0.00299    |
# |    value_loss           | 2.22e-05    |
# -----------------------------------------
# Early stopping at step 6 due to reaching max kl: 0.02
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 461          |
# |    iterations           | 51           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0143485665 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.689       |
# |    explained_variance   | -0.112       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0302      |
# |    n_updates            | 474          |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 1.92e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 462         |
# |    iterations           | 52          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.012574803 |
# |    clip_fraction        | 0.00786     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.689      |
# |    explained_variance   | -0.218      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0566     |
# |    n_updates            | 484         |
# |    policy_gradient_loss | -0.00156    |
# |    value_loss           | 1.3e-05     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 53           |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0049376087 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.691       |
# |    explained_variance   | -0.53        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0258      |
# |    n_updates            | 494          |
# |    policy_gradient_loss | -0.000421    |
# |    value_loss           | 1.15e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 464          |
# |    iterations           | 54           |
# |    time_elapsed         | 237          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0017297484 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.689       |
# |    explained_variance   | -0.166       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0142      |
# |    n_updates            | 504          |
# |    policy_gradient_loss | -0.000309    |
# |    value_loss           | 9.01e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 465          |
# |    iterations           | 55           |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0032447241 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | -0.426       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00504     |
# |    n_updates            | 514          |
# |    policy_gradient_loss | -0.000471    |
# |    value_loss           | 7.44e-06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 466           |
# |    iterations           | 56            |
# |    time_elapsed         | 245           |
# |    total_timesteps      | 114688        |
# | train/                  |               |
# |    approx_kl            | 0.00022725199 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.688        |
# |    explained_variance   | -0.309        |
# |    learning_rate        | 5e-05         |
# |    loss                 | -0.027        |
# |    n_updates            | 524           |
# |    policy_gradient_loss | -0.000105     |
# |    value_loss           | 9.57e-06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 467           |
# |    iterations           | 57            |
# |    time_elapsed         | 249           |
# |    total_timesteps      | 116736        |
# | train/                  |               |
# |    approx_kl            | 0.00035917925 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.689        |
# |    explained_variance   | -0.581        |
# |    learning_rate        | 5e-05         |
# |    loss                 | -0.0227       |
# |    n_updates            | 534           |
# |    policy_gradient_loss | 0.000136      |
# |    value_loss           | 7.14e-06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 58           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0024224296 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.688       |
# |    explained_variance   | -0.471       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0123      |
# |    n_updates            | 544          |
# |    policy_gradient_loss | -0.0005      |
# |    value_loss           | 7.28e-06     |
# ------------------------------------------
# Early stopping at step 5 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 59          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.013598728 |
# |    clip_fraction        | 0.00145     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.69       |
# |    explained_variance   | -0.392      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0201      |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 8.8e-06     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 60           |
# |    time_elapsed         | 260          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0068816966 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.679       |
# |    explained_variance   | -0.0839      |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0282      |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 9.59e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 472          |
# |    iterations           | 61           |
# |    time_elapsed         | 264          |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0026066531 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.673       |
# |    explained_variance   | -0.0608      |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0228      |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00021     |
# |    value_loss           | 4.52e-05     |
# ------------------------------------------
# Early stopping at step 9 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 473         |
# |    iterations           | 62          |
# |    time_elapsed         | 268         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.015148824 |
# |    clip_fraction        | 0.00595     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -0.233      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0351     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 1.14e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 63          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# ...
# | train/                  |              |
# |    approx_kl            | 0.0044994424 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.594       |
# |    explained_variance   | 0.058        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0002      |
# |    n_updates            | 7788         |
# |    policy_gradient_loss | -0.000615    |
# |    value_loss           | 5.17e-07     |
# ------------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 524          |
# |    iterations           | 1346         |
# |    time_elapsed         | 5258         |
# |    total_timesteps      | 2756608      |
# | train/                  |              |
# |    approx_kl            | 0.0047972114 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.48        |
# |    explained_variance   | 0.317        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0162      |
# |    n_updates            | 7791         |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 3.3e-06      |
# ------------------------------------------
# Early stopping at step 9 due to reaching max kl: 0.02
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 1347         |
# |    time_elapsed         | 5265         |
# |    total_timesteps      | 2758656      |
# | train/                  |              |
# |    approx_kl            | 0.0031335654 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.398       |
# |    explained_variance   | 0.139        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.011        |
# |    n_updates            | 7801         |
# |    policy_gradient_loss | -4.04e-05    |
# |    value_loss           | 6.6e-06      |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 1348         |
# |    time_elapsed         | 5269         |
# |    total_timesteps      | 2760704      |
# | train/                  |              |
# |    approx_kl            | 0.0045604585 |
# |    clip_fraction        | 0.0667       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.451       |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00953     |
# |    n_updates            | 7803         |
# |    policy_gradient_loss | 0.00219      |
# |    value_loss           | 7.85e-06     |
# ------------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 1349        |
# |    time_elapsed         | 5273        |
# |    total_timesteps      | 2762752     |
# | train/                  |             |
# |    approx_kl            | 0.014621201 |
# |    clip_fraction        | 0.0175      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | -0.257      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0123      |
# |    n_updates            | 7805        |
# |    policy_gradient_loss | 0.00279     |
# |    value_loss           | 8.69e-07    |
# -----------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.02
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 1350         |
# |    time_elapsed         | 5278         |
# |    total_timesteps      | 2764800      |
# | train/                  |              |
# |    approx_kl            | 0.0030926687 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.596       |
# |    explained_variance   | 0.307        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.03         |
# |    n_updates            | 7809         |
# |    policy_gradient_loss | -0.000364    |
# |    value_loss           | 9.86e-07     |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 1351         |
# |    time_elapsed         | 5282         |
# |    total_timesteps      | 2766848      |
# | train/                  |              |
# |    approx_kl            | 0.0073694945 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.546       |
# |    explained_variance   | 0.306        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0346      |
# |    n_updates            | 7810         |
# |    policy_gradient_loss | 0.009        |
# |    value_loss           | 9.07e-07     |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 1352        |
# |    time_elapsed         | 5286        |
# |    total_timesteps      | 2768896     |
# | train/                  |             |
# |    approx_kl            | 0.004344763 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.488      |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 4.61e-05    |
# |    n_updates            | 7811        |
# |    policy_gradient_loss | 0.000955    |
# |    value_loss           | 3.73e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 1353         |
# |    time_elapsed         | 5291         |
# |    total_timesteps      | 2770944      |
# | train/                  |              |
# |    approx_kl            | 0.0054014986 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.472       |
# |    explained_variance   | 0.0731       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0154      |
# |    n_updates            | 7821         |
# |    policy_gradient_loss | -0.000552    |
# |    value_loss           | 1e-06        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 1354         |
# |    time_elapsed         | 5298         |
# |    total_timesteps      | 2772992      |
# | train/                  |              |
# |    approx_kl            | 0.0030451105 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.423       |
# |    explained_variance   | -0.454       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0248      |
# |    n_updates            | 7831         |
# |    policy_gradient_loss | 0.000198     |
# |    value_loss           | 1.04e-06     |
# ------------------------------------------
# Early stopping at step 5 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 1355        |
# |    time_elapsed         | 5303        |
# |    total_timesteps      | 2775040     |
# | train/                  |             |
# |    approx_kl            | 0.009074766 |
# |    clip_fraction        | 0.0642      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.398      |
# |    explained_variance   | -1.45       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0161     |
# |    n_updates            | 7837        |
# |    policy_gradient_loss | 4.76e-07    |
# |    value_loss           | 1.56e-06    |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 523       |
# |    iterations           | 1356      |
# |    time_elapsed         | 5306      |
# |    total_timesteps      | 2777088   |
# | train/                  |           |
# |    approx_kl            | 0.0020207 |
# |    clip_fraction        | 0.0395    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.338    |
# |    explained_variance   | -0.919    |
# |    learning_rate        | 5e-05     |
# |    loss                 | -0.0165   |
# |    n_updates            | 7839      |
# |    policy_gradient_loss | -0.000918 |
# |    value_loss           | 4.52e-06  |
# ---------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 1357        |
# |    time_elapsed         | 5309        |
# |    total_timesteps      | 2779136     |
# | train/                  |             |
# |    approx_kl            | 0.005095942 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.387      |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0395      |
# |    n_updates            | 7840        |
# |    policy_gradient_loss | 0.00356     |
# |    value_loss           | 4.6e-06     |
# -----------------------------------------
# Early stopping at step 3 due to reaching max kl: 0.02
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 1358         |
# |    time_elapsed         | 5312         |
# |    total_timesteps      | 2781184      |
# | train/                  |              |
# |    approx_kl            | 0.0036634377 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.397       |
# |    explained_variance   | -0.145       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00121     |
# |    n_updates            | 7844         |
# |    policy_gradient_loss | 0.00135      |
# |    value_loss           | 1.57e-06     |
# ------------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 1359        |
# |    time_elapsed         | 5315        |
# |    total_timesteps      | 2783232     |
# | train/                  |             |
# |    approx_kl            | 0.002819265 |
# |    clip_fraction        | 0.0429      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.466      |
# |    explained_variance   | 0.0836      |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0274     |
# |    n_updates            | 7847        |
# |    policy_gradient_loss | -0.0014     |
# |    value_loss           | 9.49e-07    |
# -----------------------------------------
# Early stopping at step 8 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 1360        |
# |    time_elapsed         | 5320        |
# |    total_timesteps      | 2785280     |
# | train/                  |             |
# |    approx_kl            | 0.002904623 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.502      |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0242     |
# |    n_updates            | 7856        |
# |    policy_gradient_loss | -0.000397   |
# |    value_loss           | 1.53e-06    |
# -----------------------------------------
# Early stopping at step 1 due to reaching max kl: 0.02
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 1361         |
# |    time_elapsed         | 5323         |
# |    total_timesteps      | 2787328      |
# | train/                  |              |
# |    approx_kl            | 0.0026331816 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | 0.256        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.025       |
# |    n_updates            | 7858         |
# |    policy_gradient_loss | 0.00292      |
# |    value_loss           | 2.43e-06     |
# ------------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 1362        |
# |    time_elapsed         | 5327        |
# |    total_timesteps      | 2789376     |
# | train/                  |             |
# |    approx_kl            | 0.005890419 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.555      |
# |    explained_variance   | 0.268       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.00766     |
# |    n_updates            | 7859        |
# |    policy_gradient_loss | -0.000882   |
# |    value_loss           | 1.88e-06    |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 1363         |
# |    time_elapsed         | 5331         |
# |    total_timesteps      | 2791424      |
# | train/                  |              |
# |    approx_kl            | 0.0023171278 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.567       |
# |    explained_variance   | 0.102        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00141     |
# |    n_updates            | 7860         |
# |    policy_gradient_loss | 0.00197      |
# |    value_loss           | 1.35e-06     |
# ------------------------------------------
# Early stopping at step 2 due to reaching max kl: 0.02
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 1364        |
# |    time_elapsed         | 5336        |
# |    total_timesteps      | 2793472     |
# | train/                  |             |
# |    approx_kl            | 0.003523681 |
# |    clip_fraction        | 0.0298      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | -0.285      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0189      |
# |    n_updates            | 7863        |
# |    policy_gradient_loss | 0.000318    |
# |    value_loss           | 8.9e-07     |
# -----------------------------------------
# Early stopping at step 0 due to reaching max kl: 0.02

# %%
training_log_path = os.path.join(log_path)

# %%
# !tensorboard --logdir={training_log_path}
